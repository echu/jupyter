# %%
import os
import time
from kafka import KafkaClient, KafkaConsumer
from kafka.common import LeaderNotAvailableError

# IP:PORT of a Kafka broker. The typical port is 9092.
KAFKA_BROKER_IP_PORT = os.getenv('KAFKA_BROKER', '192.168.86.10:9092')
print("KAFKA BROKER: " + KAFKA_BROKER_IP_PORT)
kafka = KafkaClient(KAFKA_BROKER_IP_PORT)

consumer = KafkaConsumer("test-topic", group_id="my_group",
                         metadata_broker_list=[KAFKA_BROKER_IP_PORT])
for message in consumer:
    # message is raw byte string -- decode if necessary!
    # e.g., for unicode: `message.decode('utf-8')`
    print(message)

# kafka.close()
# Out:
# WARNING:kafka.consumer.kafka:Converting configuration key 'client_id' to bytes
# WARNING:kafka.consumer.kafka:Converting configuration key 'group_id' to bytes
# KAFKA BROKER: 172.31.15.171:9092
# KafkaMessage(topic=b'test-topic', partition=0, offset=5, key=None, value=b'The medium is the message.')
# KafkaMessage(topic=b'test-topic', partition=1, offset=6, key=None, value=b'The medium is the message.')
# KafkaMessage(topic=b'test-topic', partition=0, offset=6, key=None, value=b'The medium is the message.')
# KafkaMessage(topic=b'test-topic', partition=1, offset=7, key=None, value=b'The medium is the message.')
# KafkaMessage(topic=b'test-topic', partition=0, offset=7, key=None, value=b'The medium is the message.')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b8da4b77cadb> in <module>()
#      11 consumer = KafkaConsumer("test-topic", group_id="my_group",
#      12                          metadata_broker_list=[KAFKA_BROKER_IP_PORT])
# ---> 13 for message in consumer:
#      14     # message is raw byte string -- decode if necessary!
#      15     # e.g., for unicode: `message.decode('utf-8')`
#
# /usr/local/lib/python3.4/dist-packages/kafka/consumer/kafka.py in __next__(self)
#     734
#     735     def __next__(self):
# --> 736         return self.next()
#     737
#     738     def _get_message_iterator(self):
#
# /usr/local/lib/python3.4/dist-packages/kafka/consumer/kafka.py in next(self)
#     337
#     338             try:
# --> 339                 return six.next(self._get_message_iterator())
#     340
#     341             # Handle batch completion
#
# /usr/local/lib/python3.4/dist-packages/kafka/consumer/kafka.py in fetch_messages(self)
#     384                                                         max_wait_time=max_wait_time,
#     385                                                         min_bytes=min_bytes,
# --> 386                                                         fail_on_error=False)
#     387         except FailedPayloadsError:
#     388             logger.warning('FailedPayloadsError attempting to fetch data from kafka')
#
# /usr/local/lib/python3.4/dist-packages/kafka/client.py in send_fetch_request(self, payloads, fail_on_error, callback, max_wait_time, min_bytes)
#     437         resps = self._send_broker_aware_request(
#     438             payloads, encoder,
# --> 439             KafkaProtocol.decode_fetch_response)
#     440
#     441         out = []
#
# /usr/local/lib/python3.4/dist-packages/kafka/client.py in _send_broker_aware_request(self, payloads, encoder_fn, decoder_fn)
#     181                     continue
#     182                 try:
# --> 183                     response = conn.recv(requestId)
#     184                 except ConnectionError as e:
#     185                     log.warning("Could not receive response to request [%s] "
#
# /usr/local/lib/python3.4/dist-packages/kafka/conn.py in recv(self, request_id)
#     149
#     150         # Read the size off of the header
# --> 151         resp = self._read_bytes(4)
#     152         (size,) = struct.unpack('>i', resp)
#     153
#
# /usr/local/lib/python3.4/dist-packages/kafka/conn.py in _read_bytes(self, num_bytes)
#      91
#      92             try:
# ---> 93                 data = self._sock.recv(min(bytes_left, 4096))
#      94
#      95                 # Receiving empty string from recv signals
#
# KeyboardInterrupt:
