# %%
import os
import time
from kafka import SimpleProducer, KafkaClient, KafkaConsumer
from kafka.common import LeaderNotAvailableError

# IP:PORT of a Kafka broker. The typical port is 9092.
KAFKA_BROKER_IP_PORT = os.getenv('KAFKA_BROKER', '192.168.86.10:9092')
print("KAFKA BROKER: " + KAFKA_BROKER_IP_PORT)
kafka = KafkaClient(KAFKA_BROKER_IP_PORT)
producer = SimpleProducer(kafka)

# Note that the application is responsible for encoding messages to type str
while True:
	print('Sending...')
	try:
		producer.send_messages(b"test-topic", b"The medium is the message.")
	except LeaderNotAvailableError:
		print('Caught a LeaderNotAvailableError. This seems to happen when auto-creating a new topic.')
	time.sleep(3)
# Out:
# KAFKA BROKER: 172.31.15.171:9092
# Sending...
# Sending...
# Sending...
# Sending...
# Sending...
# Sending...
# Sending...
# Sending...
# Sending...
# Sending...
# Sending...
# Sending...
# Sending...
# Sending...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8a10f3122c4b> in <module>()
#      17         except LeaderNotAvailableError:
#      18                 print('Caught a LeaderNotAvailableError. This seems to happen when auto-creating a new topic.')
# ---> 19         time.sleep(3)
#      20
#
# KeyboardInterrupt:
